# %%
#Script to modify the model iJN1463.xml for FLYCOP simulation
#11/03/21
#Isabel de Moya Clark
from cobra import Reaction
from cobra import Metabolite

import cobra as cb
import cometspy as c

# %%
defaultModel_3_model=c.model("defaultModel-3-consumoSeparado_1.cmd")

plasticDegradationEstrategy3_dPCA_model=c.model("plasticDegradationEstrategy3-dPCA_10.cmd")

cmd_models=[defaultModel_3_model, plasticDegradationEstrategy3_dPCA_model]
cmd_models

# %%
all_exchanged_mets = []
for m in cmd_models: #reeplazar self.models por una lista con tus dos modelos que tienen que ser modelos cometspy. 
    all_exchanged_mets.extend(m.get_exchange_metabolites())
    all_exchanged_mets = sorted(list(set(list(all_exchanged_mets)))) #se va a quedar con elementos no

# %%
all_exchanged_mets
# Out:
# ['12dgr160_e',
#  '12dgr180_e',
#  '13dampp_e',
#  '14bdo_e',
#  '15dap_e',
#  '1ag160_e',
#  '1ag180_e',
#  '1ag181d9_e',
#  '1ag182d9d12_e',
#  '25dkglcn_e',
#  '26dap__M_e',
#  '2ameph_e',
#  '2ddglcn_e',
#  '2dhglcn_e',
#  '2m35mdntha_e',
#  '34dhbz_e',
#  '34dhcinm_e',
#  '34dhphe_e',
#  '35dnta_e',
#  '3h4atb_e',
#  '3mb_e',
#  '3oxoadp_e',
#  '4abut_e',
#  '4hbz_e',
#  '4hpro_DC_e',
#  '4hpro_LT_e',
#  '5aptn_e',
#  '5mcsn_e',
#  '5oxpro_e',
#  '6atha_e',
#  '6hnac_e',
#  'C80aPHA_e',
#  'C80aPHA_e_default',
#  'D_met_e',
#  'LalaLglu_e',
#  'Ncbmpts_e',
#  'R3hdec4e_e',
#  'R_3h4atba_e',
#  'R_3h6atha_e',
#  'R_3hcmrs7e_e',
#  'R_3hdcaa_e',
#  'R_3hdd5ea_e',
#  'R_3hdd6e_e',
#  'R_3hdda_e',
#  'R_3hhdca_e',
#  'R_3hhpa_e',
#  'R_3hhxa_e',
#  'R_3hnonaa_e',
#  'R_3hocta_e',
#  'R_3hpba_e',
#  'R_3hpdeca_e',
#  'R_3hphpa_e',
#  'R_3hphxa_e',
#  'R_3hpnona_e',
#  'R_3hpocta_e',
#  'R_3hppta_e',
#  'R_3hpt_e',
#  'R_3htd58e_e',
#  'R_3htd5e_e',
#  'R_3httdca_e',
#  'T4hcinnm_e',
# ...
